# %%
import pandas as pd
import glob
import re
from collections import OrderedDict
import numpy as np
def convert_to_np_vec(a1):
    return np.array([int(x) for x in a1])
L= glob.glob("bid_ask_out/f_bid_ask_2017-11-22-23*")
L.sort()
print L
M=[]
for ll in L:
    f2 = open(ll,"r")
    r2 = f2.read()
    rt2 = r2.replace("\n","\t")
    rexp2 = re.findall(r'[A-Z]+,[a-z]+: ?[0-9]+\.[0-9]+[\t0-9]+',rt2)
    D = OrderedDict()
    for ii in rexp2:
        k = ii.split(",")[0]
        if k in D.keys():
            ba = ii.split(",")[1].split(":")[0]
            if ba in D[k].keys():
                prs = ii.split(":")[1].split("\t")[0].replace(" ","")
                if prs in D[k][ba].keys():
                    D[k][ba][prs] = np.append(D[k][ba][prs],convert_to_np_vec(ii.split("\t")[1:-1]))
                else:
                    D[k][ba][prs] = convert_to_np_vec(ii.split("\t")[1:-1])
            else:
                D[k][ba] = OrderedDict()
                
                D[k][ba][ii.split(":")[1].split("\t")[0].replace(" ","")] = convert_to_np_vec(ii.split("\t")[1:-1])
        else:
            M1 = OrderedDict()
            M1[ii.split(":")[1].split("\t")[0].replace(" ","")] = convert_to_np_vec(ii.split("\t")[1:-1])
            M2 =OrderedDict()
            M2[ii.split(",")[1].split(":")[0]] = M1
            D[k] = M2
    """
    for k in D.keys():
        print k
        for kk in D[k].keys():
            print kk,D[k][kk].items()
    """
    M.append(D)
o = open("out_diff.txt","w")
price_changes_counter = 0
positive_changes_counter = 0
negative_changes_counter = 0
unchanged_counter = 0
for ind in range(1,len(M)):
    mm = M[ind]
    mb = M[ind-1]
    for k in mm.keys():
        if k in mb:
            o.write("..............................\n")
            for kk in mm[k].keys():
                o.write("%s,%s"%(k,kk))
                o.write(("*"*50)+"\n")
                o.write("before\t%s%s%s%s%s"%(mb[k][kk],"\nafter\t",mm[k][kk],"\n",("-"*50)+"\n"))
                x1 = round(float(mm[k][kk].keys()[0]),2)
                x2 = round(float(mb[k][kk].keys()[0]),2)
                if x1>x2:
                    positive_changes_counter+=1
                elif x1<x2:
                    negative_changes_counter+=1
                else:
                    unchanged_counter+=1
                if x1!=x2:
                    price_changes_counter+=1
print("positive_changes_counter:%d"%positive_changes_counter)
print("negative_changes_counter:%d"%negative_changes_counter)
print("price_changes_counter:%d"%price_changes_counter)
print("unchanged_counter:%d"%unchanged_counter)
# Out:
# ['bid_ask_out/f_bid_ask_2017-11-22-23-00-02.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-07.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-11.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-16.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-20.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-25.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-29.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-33.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-39.txt', 'bid_ask_out/f_bid_ask_2017-11-22-23-00-44.txt']
# 28.48 28.48
# 28.49 28.49
# 28.48 28.48
# 28.49 28.49
# 265.08 265.09
# 265.14 265.12
# 28.48 28.48
# 28.49 28.49
# 265.08 265.08
# 265.14 265.14
# 28.48 28.48
# 28.49 28.49
# 265.09 265.08
# 265.13 265.14
# 28.48 28.48
# 28.49 28.49
# 265.16 265.09
# 265.18 265.13
# 28.48 28.48
# 28.49 28.49
# 265.16 265.16
# 265.18 265.18
# 28.48 28.48
# 28.49 28.49
# 265.15 265.16
# 265.17 265.18
# 28.48 28.48
# 28.49 28.49
# 265.16 265.15
# 265.17 265.17
# 28.48 28.48
# 28.49 28.49
# 265.13 265.16
# 265.16 265.17
